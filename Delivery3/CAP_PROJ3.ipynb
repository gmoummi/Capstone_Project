# %% [markdown]
# ### Capstone Project

# %%
#import libraries

import zipfile
import requests

import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt

import statistics
import scipy.stats

import seaborn as sns

from sklearn import preprocessing
from sklearn.cluster import KMeans
from sklearn import metrics

from math import pi

# %% [markdown]
# ### Importing the data

# %%
#Download the zip file from URL

url = 'https://ftp.cdc.gov/pub/Health_Statistics/NCHS/Datasets/CHDI/chsi_dataset.zip'
target_path = 'DATA606.zip'

response = requests.get(url, stream=True)
handle = open(target_path, "wb")
for chunk in response.iter_content(chunk_size=512):
    if chunk:  # filter out keep-alive new chunks
        handle.write(chunk)
handle.close()

# %%
#define the two dataframes

zf = zipfile.ZipFile('DATA606.zip')
#I have over 140 columns and I will only need select ones which I've defined in the lists below
#demographics
dem_col= ['CHSI_County_Name','County_FIPS_Code','CHSI_State_Name','State_FIPS_Code', 'CHSI_State_Abbr', 'Population_Size', 'Poverty','Age_19_Under', 'Age_19_64', 'Age_65_84', 'Age_85_and_Over']
#SummaryMeasuresOfHealth
heal_mea_col= ['CHSI_County_Name','County_FIPS_Code','CHSI_State_Name','State_FIPS_Code', 'CHSI_State_Abbr', 'ALE']
#PreventiveServicesUse
prev_col= ['CHSI_County_Name','County_FIPS_Code','CHSI_State_Name','State_FIPS_Code', 'CHSI_State_Abbr', 'Pap_Smear', 'Mammogram', 'Proctoscopy', 'Pneumo_Vax', 'Flu_Vac']
#MeasuresOfBirthAndDeath
mbd_col= ['CHSI_County_Name','County_FIPS_Code','CHSI_State_Name','State_FIPS_Code', 'CHSI_State_Abbr', 'LBW', 'Premature', 'Late_Care', 'Infant_Mortality', 'Brst_Cancer', 'Col_Cancer', 'CHD', 'Lung_Cancer', 'Stroke', 'Total_Deaths' ]
#RiskFactorsAndAccessToCare
risk_col= ['CHSI_County_Name', 'County_FIPS_Code','CHSI_State_Name','State_FIPS_Code', 'CHSI_State_Abbr', 'Obesity', 'High_Blood_Pres', 'Diabetes', 'Elderly_Medicare','Disabled_Medicare', 'Uninsured', 'Prim_Care_Phys_Rate', 'Dentist_Rate', 'Community_Health_Center_Ind']

#extract csv file from zip file/define dataframes
df0 = pd.read_csv(zf.open('DEMOGRAPHICS.csv'), usecols= dem_col)
df1 = pd.read_csv(zf.open('SUMMARYMEASURESOFHEALTH.csv'), usecols= heal_mea_col)
df2 = pd.read_csv(zf.open('PREVENTIVESERVICESUSE.csv'), usecols= prev_col)
df3 = pd.read_csv(zf.open('MEASURESOFBIRTHANDDEATH.csv'), usecols= mbd_col) 
df4 = pd.read_csv(zf.open('RISKFACTORSANDACCESSTOCARE.csv'), usecols= risk_col)
pd.set_option('display.max_columns', 150)

# %%
#Merge df0, df1, df2, and df3
df= df0.merge(df1).merge(df2).merge(df3).merge(df4)
#display 5 first rows
df.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
# 2                1                 5          Barbour         Alabama
# 3                1                 7             Bibb         Alabama
# 4                1                 9           Blount         Alabama
#
#   CHSI_State_Abbr  Population_Size  Poverty  Age_19_Under  Age_19_64  \
# 0              AL            48612     10.4          26.9       62.3
# 1              AL           162586     10.2          23.5       60.3
# 2              AL            28414     22.1          24.3       62.5
# 3              AL            21516     16.8          24.6       63.3
# 4              AL            55725     11.9          24.5       62.1
#
#    Age_65_84  Age_85_and_Over   ALE  Pap_Smear  Mammogram  Proctoscopy  \
# 0        9.8              0.9  74.9    -1111.1    -1111.1      -1111.1
# 1       14.5              1.8  76.6       86.1       82.0         44.1
# 2       11.6              1.6  74.5    -1111.1    -1111.1      -1111.1
# 3       10.9              1.2  73.2    -1111.1    -1111.1      -1111.1
# 4       12.1              1.3  76.1       87.2    -1111.1      -1111.1
#
#    Pneumo_Vax  Flu_Vac   LBW  Premature  Late_Care  Infant_Mortality  \
# 0     -1111.1  -1111.1   8.1       14.3       12.9               5.9
# 1        58.7     61.8   8.6       15.3       15.3               7.1
# 2     -1111.1  -1111.1  11.0       16.7       26.0               7.1
# 3     -1111.1  -1111.1   8.7       13.7       16.3               9.8
# 4     -1111.1  -1111.1   7.6       12.8       16.7               9.0
#
#    Brst_Cancer  Col_Cancer    CHD  Lung_Cancer  Stroke  Total_Deaths  Obesity  \
# 0         34.1        15.9  172.4         65.3    73.9        1867.0     24.5
# 1         22.5        15.3  156.5         62.1    48.7        4388.0     23.6
# 2         30.5        23.4   95.3         70.6    84.5        1538.0     25.6
# 3         30.1        17.4  184.7         64.6   144.6        2012.0  -1111.1
# 4         30.2        16.8  148.2         71.7    47.3        2453.0     24.2
#
#    High_Blood_Pres  Diabetes  Uninsured  Elderly_Medicare  Disabled_Medicare  \
# 0             29.1      14.2       5690              4762               1209
# 1             30.5       7.2      19798             22635               3839
# 2          -1111.1       6.6       5126              3288               1092
# 3          -1111.1      13.1       3315              2390                974
# 4          -1111.1       8.4       8131              5019               1300
#
#    Prim_Care_Phys_Rate  Dentist_Rate  Community_Health_Center_Ind
# 0                 45.3          22.6                            1
# 1                 67.0          30.8                            1
# 2                 45.8          24.6                            1
# 3                 41.8          18.6                            1
# 4                 16.2          10.8                            2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3141 entries, 0 to 3140
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   State_FIPS_Code              3141 non-null   int64
#  1   County_FIPS_Code             3141 non-null   int64
#  2   CHSI_County_Name             3141 non-null   object
#  3   CHSI_State_Name              3141 non-null   object
#  4   CHSI_State_Abbr              3141 non-null   object
#  5   Population_Size              3141 non-null   int64
#  6   Poverty                      3141 non-null   float64
#  7   Age_19_Under                 3141 non-null   float64
#  8   Age_19_64                    3141 non-null   float64
#  9   Age_65_84                    3141 non-null   float64
#  10  Age_85_and_Over              3141 non-null   float64
#  11  ALE                          3141 non-null   float64
#  12  Pap_Smear                    3141 non-null   float64
#  13  Mammogram                    3141 non-null   float64
#  14  Proctoscopy                  3141 non-null   float64
#  15  Pneumo_Vax                   3141 non-null   float64
#  16  Flu_Vac                      3141 non-null   float64
#  17  LBW                          3141 non-null   float64
#  18  Premature                    3141 non-null   float64
#  19  Late_Care                    3141 non-null   float64
#  20  Infant_Mortality             3141 non-null   float64
#  21  Brst_Cancer                  3141 non-null   float64
#  22  Col_Cancer                   3141 non-null   float64
#  23  CHD                          3141 non-null   float64
#  24  Lung_Cancer                  3141 non-null   float64
#  25  Stroke                       3141 non-null   float64
#  26  Total_Deaths                 3141 non-null   float64
#  27  Obesity                      3141 non-null   float64
#  28  High_Blood_Pres              3141 non-null   float64
#  29  Diabetes                     3141 non-null   float64
#  30  Uninsured                    3141 non-null   int64
#  31  Elderly_Medicare             3141 non-null   int64
#  32  Disabled_Medicare            3141 non-null   int64
#  33  Prim_Care_Phys_Rate          3141 non-null   float64
#  34  Dentist_Rate                 3141 non-null   float64
#  35  Community_Health_Center_Ind  3141 non-null   int64
# dtypes: float64(26), int64(7), object(3)
# memory usage: 907.9+ KB

# %% [markdown]
# ### Exploratory Data Analysis-Data Cleaning

# %%
#add a county column that contains the county and state.
df.insert(3, 'county', df['CHSI_County_Name']+ '_'+ df['CHSI_State_Name'])

#Based on dataset documentation, negative values indicate missing or unreported data. 
#I replace the negative values with NaN so I can have accurate statistics 
df_clean = df.replace({ -1111.1: np.nan, -2222.2: np.nan, -2222.0: np.nan})

#Fill NaN values with the averages. Deleting columns can result in huge loss of important data.
df_clean.fillna(df_clean.mean(), inplace= True)

#Normalization
#normalize uninsured. Number to percentage.
df_clean['Uninsured%']= df_clean['Uninsured']/df_clean['Population_Size']*100

#other columns are already percentages or per 100000 population and don't need any normalization

# %%
#top 5 rows
df_clean.head()
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name           county  \
# 0              1.0               1.0          Autauga  Autauga_Alabama
# 1              1.0               3.0          Baldwin  Baldwin_Alabama
# 2              1.0               5.0          Barbour  Barbour_Alabama
# 3              1.0               7.0             Bibb     Bibb_Alabama
# 4              1.0               9.0           Blount   Blount_Alabama
#
#   CHSI_State_Name CHSI_State_Abbr  Population_Size  Poverty  Age_19_Under  \
# 0         Alabama              AL          48612.0     10.4          26.9
# 1         Alabama              AL         162586.0     10.2          23.5
# 2         Alabama              AL          28414.0     22.1          24.3
# 3         Alabama              AL          21516.0     16.8          24.6
# 4         Alabama              AL          55725.0     11.9          24.5
#
#    Age_19_64  Age_65_84  Age_85_and_Over   ALE  Pap_Smear  Mammogram  \
# 0       62.3        9.8              0.9  74.9  82.009561   80.03255
# 1       60.3       14.5              1.8  76.6  86.100000   82.00000
# 2       62.5       11.6              1.6  74.5  82.009561   80.03255
# 3       63.3       10.9              1.2  73.2  82.009561   80.03255
# 4       62.1       12.1              1.3  76.1  87.200000   80.03255
#
#    Proctoscopy  Pneumo_Vax    Flu_Vac   LBW  Premature  Late_Care  \
# 0    43.145354   65.526638  69.432507   8.1       14.3       12.9
# 1    44.100000   58.700000  61.800000   8.6       15.3       15.3
# 2    43.145354   65.526638  69.432507  11.0       16.7       26.0
# 3    43.145354   65.526638  69.432507   8.7       13.7       16.3
# 4    43.145354   65.526638  69.432507   7.6       12.8       16.7
#
#    Infant_Mortality  Brst_Cancer  Col_Cancer    CHD  Lung_Cancer  Stroke  \
# 0               5.9         34.1        15.9  172.4         65.3    73.9
# 1               7.1         22.5        15.3  156.5         62.1    48.7
# 2               7.1         30.5        23.4   95.3         70.6    84.5
# 3               9.8         30.1        17.4  184.7         64.6   144.6
# 4               9.0         30.2        16.8  148.2         71.7    47.3
#
#    Total_Deaths    Obesity  High_Blood_Pres  Diabetes  Uninsured  \
# 0        1867.0  24.500000        29.100000      14.2     5690.0
# 1        4388.0  23.600000        30.500000       7.2    19798.0
# 2        1538.0  25.600000        26.480946       6.6     5126.0
# 3        2012.0  24.145189        26.480946      13.1     3315.0
# 4        2453.0  24.200000        26.480946       8.4     8131.0
#
#    Elderly_Medicare  Disabled_Medicare  Prim_Care_Phys_Rate  Dentist_Rate  \
# 0            4762.0             1209.0                 45.3          22.6
# 1           22635.0             3839.0                 67.0          30.8
# 2            3288.0             1092.0                 45.8          24.6
# 3            2390.0              974.0                 41.8          18.6
# 4            5019.0             1300.0                 16.2          10.8
#
#    Community_Health_Center_Ind  Uninsured%
# 0                          1.0   11.704929
# 1                          1.0   12.176940
# 2                          1.0   18.040403
# 3                          1.0   15.407139
# 4                          2.0   14.591297

# %%
#general statistics 
df_clean.describe().transpose()
# Out:
#                               count          mean            std        min  \
# State_FIPS_Code              3141.0     30.304680      15.134423   1.000000
# County_FIPS_Code             3141.0    103.716651     107.999484   1.000000
# Population_Size              3141.0  94368.164279  306431.655763  62.000000
# Poverty                      3141.0     13.350159       4.882530   2.200000
# Age_19_Under                 3141.0     24.806527       3.281777   1.400000
# Age_19_64                    3141.0     60.289398       3.356056  47.600000
# Age_65_84                    3141.0     12.789430       3.334035   2.100000
# Age_85_and_Over              3141.0      2.115409       0.949119   0.100000
# ALE                          3141.0     76.322874       1.996864  66.600000
# Pap_Smear                    3141.0     82.009561       3.757744  58.900000
# Mammogram                    3141.0     80.032550       3.153324  58.300000
# Proctoscopy                  3141.0     43.145354       4.910214   7.000000
# Pneumo_Vax                   3141.0     65.526638       3.247622  35.700000
# Flu_Vac                      3141.0     69.432507       3.288601  44.900000
# LBW                          3141.0      7.569421       1.837658   2.100000
# Premature                    3141.0     11.877401       2.392148   5.100000
# Late_Care                    3141.0     17.791293       6.655943   2.000000
# Infant_Mortality             3141.0      7.410028       2.761960   0.000000
# Brst_Cancer                  3141.0     26.325236       5.468999   9.500000
# Col_Cancer                   3141.0     21.354870       4.503386   9.000000
# CHD                          3141.0    191.066496      48.127272  59.800000
# Lung_Cancer                  3141.0     58.639830      14.279114  10.500000
# Stroke                       3141.0     63.388484      15.731224  21.600000
# Total_Deaths                 3141.0   3107.701592    6431.731936   5.000000
# Obesity                      3141.0     24.145189       4.126357   4.200000
# High_Blood_Pres              3141.0     26.480946       3.783796   7.200000
# Diabetes                     3141.0      7.810188       2.572103   0.500000
# Uninsured                    3141.0  12659.020395   54602.843029  11.000000
# Elderly_Medicare             3141.0  11009.276206   31360.296629  11.000000
# Disabled_Medicare            3141.0   1900.449662    4680.274398  12.000000
# Prim_Care_Phys_Rate          3141.0     57.562464      44.793770   0.000000
# Dentist_Rate                 3141.0     32.164809      21.500315   0.000000
# Community_Health_Center_Ind  3141.0      1.550780       0.497494   1.000000
# Uninsured%                   3141.0     17.790236     203.298221   2.299462
#
#                                       25%           50%           75%  \
# State_FIPS_Code                 18.000000     29.000000     45.000000
# County_FIPS_Code                35.000000     79.000000    133.000000
# Population_Size              11211.000000  25235.000000  64040.000000
# Poverty                          9.800000     12.600000     16.200000
# Age_19_Under                    22.700000     24.600000     26.400000
# Age_19_64                       58.300000     60.300000     62.300000
# Age_65_84                       10.700000     12.500000     14.700000
# Age_85_and_Over                  1.500000      1.900000      2.600000
# ALE                             75.000000     76.500000     77.700000
# Pap_Smear                       82.009561     82.009561     82.400000
# Mammogram                       80.032550     80.032550     80.032550
# Proctoscopy                     43.145354     43.145354     43.145354
# Pneumo_Vax                      65.526638     65.526638     65.526638
# Flu_Vac                         69.432507     69.432507     69.432507
# LBW                              6.300000      7.400000      8.600000
# Premature                       10.200000     11.700000     13.200000
# Late_Care                       13.100000     17.100000     21.200000
# Infant_Mortality                 5.600000      7.300000      8.700000
# Brst_Cancer                     23.100000     26.325236     28.900000
# Col_Cancer                      18.300000     21.300000     23.700000
# CHD                            156.900000    187.800000    221.200000
# Lung_Cancer                     49.500000     58.639830     67.500000
# Stroke                          53.100000     61.700000     71.400000
# Total_Deaths                  1164.000000   1887.000000   2859.000000
# Obesity                         22.500000     24.145189     25.800000
# High_Blood_Pres                 26.400000     26.480946     26.480946
# Diabetes                         6.200000      7.810188      9.100000
# Uninsured                     1551.000000   3434.000000   8126.000000
# Elderly_Medicare              1667.000000   3534.000000   8428.000000
# Disabled_Medicare              291.000000    716.000000   1722.000000
# Prim_Care_Phys_Rate             30.500000     50.600000     74.700000
# Dentist_Rate                    18.700000     30.000000     43.300000
# Community_Health_Center_Ind      1.000000      2.000000      2.000000
# Uninsured%                      10.524444     13.348242     17.054379
#
#                                       max
# State_FIPS_Code              5.600000e+01
# County_FIPS_Code             8.400000e+02
# Population_Size              9.935475e+06
# Poverty                      3.620000e+01
# Age_19_Under                 4.720000e+01
# Age_19_64                    8.330000e+01
# Age_65_84                    2.920000e+01
# Age_85_and_Over              7.600000e+00
# ALE                          8.130000e+01
# Pap_Smear                    9.820000e+01
# Mammogram                    9.590000e+01
# Proctoscopy                  6.630000e+01
# Pneumo_Vax                   8.840000e+01
# Flu_Vac                      8.790000e+01
# LBW                          1.560000e+01
# Premature                    2.350000e+01
# Late_Care                    5.350000e+01
# Infant_Mortality             2.370000e+01
# Brst_Cancer                  6.230000e+01
# Col_Cancer                   4.630000e+01
# CHD                          4.129000e+02
# Lung_Cancer                  1.664000e+02
# Stroke                       1.758000e+02
# Total_Deaths                 1.810180e+05
# Obesity                      4.260000e+01
# High_Blood_Pres              4.710000e+01
# Diabetes                     2.080000e+01
# Uninsured                    2.167891e+06
# Elderly_Medicare             9.115900e+05
# Disabled_Medicare            1.181900e+05
# Prim_Care_Phys_Rate          5.812000e+02
# Dentist_Rate                 3.779000e+02
# Community_Health_Center_Ind  2.000000e+00
# Uninsured%                   1.140452e+04

# %% [markdown]
# ### Exploratory Data Analysis-Visualization

# %%
#get uninsured% averages for each state

unin_y= []
state_x=[]
for i in df_clean.CHSI_State_Name.unique():
    a= statistics.mean(df_clean[df_clean['CHSI_State_Name']== i]['Uninsured%'])
    unin_y.append(a)
    state_x.append(i)
    
d = {'States':state_x,'Uninsured%avg':unin_y}
uninsured_df= pd.DataFrame(d)
uninsured_df.sort_values('Uninsured%avg', inplace= True)

# %%
# num of uninsured across states 


x= uninsured_df['States']
y= uninsured_df['Uninsured%avg']
fig = plt.figure(figsize = (25, 10)) 
  
# creating the bar plot 
plt.bar(x, y, color ='crimson',  
        width = 0.8) 
  
plt.xticks(fontsize=20, rotation=90)
plt.ylim((0,100))
plt.ylabel("% of uninsured", fontsize=20) 
plt.title("% of Uninsured individuals in the US", fontsize=20) 

#plt.savefig('Uninsured%byState.png')
plt.show()

# %%
#get PCPs No. averages for each state

PCPs_y=[]
state_x=[]
for i in df_clean.CHSI_State_Name.unique():
    a= statistics.mean(df_clean[df_clean['CHSI_State_Name']== i]['Prim_Care_Phys_Rate'])
    PCPs_y.append(a)
    state_x.append(i)
    
d = {'States':state_x,'PCPsNo.':PCPs_y}
PCPs_df= pd.DataFrame(d)
PCPs_df.sort_values('PCPsNo.', inplace= True)

# %%
# num of PCPs across states 

x= PCPs_df['States']
y= PCPs_df['PCPsNo.']
fig = plt.figure(figsize = (25, 10)) 

# creating the bar plot 
plt.bar(x, y, color = 'skyblue',  
        width = 0.8) 
  
plt.xticks(fontsize=20, rotation=90)
#plt.ylim((0,100))
plt.ylabel("No. of PCPs per 100000 pop.", fontsize=20) 
plt.title("No. of PCPs per 100000 pop. across US States", fontsize=20) 

#plt.savefig('PCPsbyState.png')
plt.show()

# %% [raw]
# df_clean.iloc[df_clean['Prim_Care_Phys_Rate'].idxmin()] # this is just for me to double check values

# %% [raw]
# #export data for Tableau
# df_clean.to_csv('updateddata.csv')

# %% [raw]
# import seaborn as sns
# sns.set(style="ticks")
# sns.pairplot(df_clean)

# %% [markdown]
# ## K-MEANS CLUSTERING
# ### This is an unlabeled dataset in which we want to group our counties. Therefore, we will leverage k-means clustering to group our data.

# %%
#K-means clustering

#select X values
X= df_clean.iloc[:, 6:-1].values

#normalize the data for kmeans
scaler = preprocessing.MinMaxScaler() 
X = scaler.fit_transform(X)

# %%
#The elbow method to find the right amount of clusters to use

wcss= []
for i in range(1,11):
    kmeans= KMeans(n_clusters=i, init='k-means++')
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# training the model and applying it on our normalized dataset
kmeans= KMeans(n_clusters=4, init='k-means++', random_state= 10)

y_pred= kmeans.fit_predict(X)
print(y_pred)
# Out:
# [0 2 0 ... 1 2 3]

# %%
#k-means silhouette coefficient score
metrics.silhouette_score(X, y_pred, metric='euclidean')
# Out:
# 0.16370334295861924

# %%
#Adding a cluster column and sorting the counties by which cluster they belong to
df_clean['cluster']= y_pred
sortcounties = df_clean.sort_values(['cluster'])

sortcounties
# Out:
#       State_FIPS_Code  County_FIPS_Code CHSI_County_Name              county  \
# 0                 1.0               1.0          Autauga     Autauga_Alabama
# 1480             28.0             163.0            Yazoo   Yazoo_Mississippi
# 1485             29.0               9.0            Barry      Barry_Missouri
# 1488             29.0              15.0           Benton     Benton_Missouri
# 1489             29.0              17.0        Bollinger  Bollinger_Missouri
# ...               ...               ...              ...                 ...
# 1238             26.0              19.0           Benzie     Benzie_Michigan
# 1643             30.0              95.0       Stillwater  Stillwater_Montana
# 1236             26.0              15.0            Barry      Barry_Michigan
# 1255             26.0              53.0          Gogebic    Gogebic_Michigan
# 3140             56.0              45.0           Weston      Weston_Wyoming
#
#      CHSI_State_Name CHSI_State_Abbr  Population_Size  Poverty  Age_19_Under  \
# 0            Alabama              AL          48612.0     10.4          26.9
# 1480     Mississippi              MS          28195.0     27.0          27.5
# 1485        Missouri              MO          35599.0     14.9          25.5
# 1488        Missouri              MO          18854.0     14.6          19.1
# 1489        Missouri              MO          12325.0     13.3          23.9
# ...              ...             ...              ...      ...           ...
# 1238        Michigan              MI          17644.0      7.8          22.7
# 1643         Montana              MT           8493.0      9.4          22.3
# 1236        Michigan              MI          59892.0      7.3          25.7
# 1255        Michigan              MI          16861.0     13.3          19.7
# 3140         Wyoming              WY           6671.0      9.9          20.1
#
#       Age_19_64  Age_65_84  Age_85_and_Over   ALE  Pap_Smear  Mammogram  \
# 0          62.3        9.8              0.9  74.9  82.009561   80.03255
# 1480       60.7       10.2              1.6  72.3  75.500000   82.50000
# 1485       58.7       14.0              1.8  75.3  82.009561   80.03255
# 1488       57.9       20.8              2.2  75.3  82.009561   80.03255
# 1489       61.2       13.0              1.8  74.9  82.009561   80.03255
# ...         ...        ...              ...   ...        ...        ...
# 1238       59.2       15.8              2.3  80.2  82.009561   80.03255
# 1643       62.8       13.3              1.6  79.3  81.300000   80.03255
# 1236       62.2       10.6              1.5  76.8  82.009561   80.03255
# 1255       58.9       17.0              4.4  76.9  82.009561   80.03255
# 3140       63.2       14.4              2.4  77.4  75.500000   67.00000
#
#       Proctoscopy  Pneumo_Vax    Flu_Vac   LBW  Premature  Late_Care  \
# 0       43.145354   65.526638  69.432507   8.1       14.3       12.9
# 1480    43.145354   65.526638  69.432507  13.1       20.4       18.4
# 1485    43.145354   65.526638  69.432507   7.7       13.3       17.9
# 1488    43.145354   65.526638  69.432507   6.7        9.8       13.8
# 1489    43.145354   65.526638  69.432507   6.6       12.5       11.5
# ...           ...         ...        ...   ...        ...        ...
# 1238    43.145354   65.526638  69.432507   6.6        9.8       18.5
# 1643    43.145354   65.526638  69.432507   5.5        9.2       12.8
# 1236    43.145354   65.526638  69.432507   7.8       11.7       14.6
# 1255    43.145354   65.526638  69.432507   7.2       10.6       16.2
# 3140    39.500000   77.300000  75.300000   8.8       10.7       18.9
#
#       Infant_Mortality  Brst_Cancer  Col_Cancer    CHD  Lung_Cancer  Stroke  \
# 0                  5.9    34.100000        15.9  172.4         65.3    73.9
# 1480              12.8    39.100000        15.2  213.7         71.0    83.8
# 1485               6.2    20.300000        18.2  252.4         67.1    77.8
# 1488               8.6    33.300000        30.6  194.4         92.4    63.3
# 1489              11.4    24.700000        24.2  228.2         69.6    70.9
# ...                ...          ...         ...    ...          ...     ...
# 1238               4.2    23.300000        15.9  226.3         55.9    52.7
# 1643               2.6    26.325236        17.6  139.8         43.5    74.6
# 1236               5.6    24.300000        20.7  157.8         52.2    63.6
# 1255               8.3    28.200000        18.3  216.1         57.6    62.9
# 3140              11.7    26.325236        32.8  126.0         58.9    47.2
#
#       Total_Deaths    Obesity  High_Blood_Pres  Diabetes  Uninsured  \
# 0           1867.0  24.500000        29.100000      14.2     5690.0
# 1480        1535.0  33.600000        26.480946       9.7     6373.0
# 1485        1932.0  26.800000        26.480946      11.5     6158.0
# 1488        2425.0  24.600000        26.480946      17.8     2788.0
# 1489        1238.0  24.145189        26.480946       9.1     1876.0
# ...            ...        ...              ...       ...        ...
# 1238        1591.0  24.145189        26.480946      10.3     1731.0
# 1643         711.0  18.800000        23.100000       5.5     1150.0
# 1236        2334.0  23.400000        30.100000       9.0     4432.0
# 1255        2617.0  24.145189        26.480946       8.1     1944.0
# 3140         629.0  24.200000        26.700000       5.7      867.0
#
#       Elderly_Medicare  Disabled_Medicare  Prim_Care_Phys_Rate  Dentist_Rate  \
# 0               4762.0             1209.0                 45.3          22.6
# 1480            3297.0              891.0                 21.3          21.3
# 1485            5828.0             1128.0                 61.8          22.5
# 1488            4030.0              899.0                 10.6          15.9
# 1489            1673.0              404.0                  8.1           8.1
# ...                ...                ...                  ...           ...
# 1238            2934.0              413.0                 45.3          22.7
# 1643            1206.0              124.0                 35.3          11.8
# 1236            6132.0              879.0                 45.1          23.4
# 1255            3914.0              582.0                 89.0          35.6
# 3140            1072.0              143.0                 45.0          30.0
#
#       Community_Health_Center_Ind  Uninsured%  cluster
# 0                             1.0   11.704929        0
# 1480                          1.0   22.603298        0
# 1485                          1.0   17.298239        0
# 1488                          1.0   14.787313        0
# 1489                          1.0   15.221095        0
# ...                           ...         ...      ...
# 1238                          2.0    9.810701        3
# 1643                          2.0   13.540563        3
# 1236                          2.0    7.399987        3
# 1255                          2.0   11.529565        3
# 3140                          2.0   12.996552        3
#
# [3141 rows x 39 columns]

# %% [raw]
# #statistics of counties in cluster 1
# sortcounties[sortcounties['cluster']== 0].describe().transpose()

# %% [raw]
# #statistics of counties in cluster 2
# sortcounties[sortcounties['cluster']== 1].describe().transpose()

# %% [raw]
# #statistics of counties in cluster 3
# sortcounties[sortcounties['cluster']== 2].describe().transpose()

# %% [raw]
# #statistics of counties in cluster 4
# sortcounties[sortcounties['cluster']== 3].describe().transpose()

# %%
#creating a dataframe with all the means of each feature in each cluster
df_clean1=df_clean[df_clean['cluster']== 0]
df_clean2=df_clean[df_clean['cluster']== 1]
df_clean3=df_clean[df_clean['cluster']== 2]
df_clean4=df_clean[df_clean['cluster']== 3]

d0= {'features':['Num of counties','Population_Size', 'Poverty', 'Age_19_Under', 'Age_19_64', 'Age_65_84',
       'Age_85_and_Over', 'Pap_Smear', 'Mammogram', 'Proctoscopy',
       'Pneumo_Vax', 'Flu_Vac', 'LBW', 'Premature', 'Late_Care',
       'Infant_Mortality', 'Brst_Cancer', 'Col_Cancer', 'CHD', 'Lung_Cancer',
       'Stroke', 'Obesity', 'High_Blood_Pres', 'Diabetes', 'Uninsured',
       'Elderly_Medicare', 'Disabled_Medicare', 'Prim_Care_Phys_Rate',
       'Dentist_Rate', 'Community_Health_Center_Ind'],
     'cluster1':[sortcounties[sortcounties['cluster']== 0]['State_FIPS_Code'].count(), df_clean1['Population_Size'].mean(), df_clean1['Poverty'].mean(), 
                 df_clean1['Age_19_Under'].mean(), df_clean1['Age_19_64'].mean(),
                 df_clean1['Age_65_84'].mean(),df_clean1['Age_85_and_Over'].mean(),
                 df_clean1['Pap_Smear'].mean(),df_clean1['Mammogram'].mean(),df_clean1['Proctoscopy'].mean(),
                 df_clean1['Pneumo_Vax'].mean(),df_clean1['Flu_Vac'].mean(),df_clean1['LBW'].mean(),
                 df_clean1['Premature'].mean(), df_clean1['Late_Care'].mean(),df_clean1['Infant_Mortality'].mean(),
                 df_clean1['Brst_Cancer'].mean(),df_clean1['Col_Cancer'].mean(),df_clean1['CHD'].mean(),
                 df_clean1['Lung_Cancer'].mean(),df_clean1['Stroke'].mean(),df_clean1['Obesity'].mean(),
                 df_clean1['High_Blood_Pres'].mean(),df_clean1['Diabetes'].mean(),df_clean1['Uninsured'].mean(),
                 df_clean1['Elderly_Medicare'].mean(),df_clean1['Disabled_Medicare'].mean(),
                 df_clean1['Prim_Care_Phys_Rate'].mean(),df_clean1['Dentist_Rate'].mean(),
                 df_clean1['Community_Health_Center_Ind'].mean()], 
     'cluster2':[sortcounties[sortcounties['cluster']== 1]['State_FIPS_Code'].count(), df_clean2['Population_Size'].mean(), df_clean2['Poverty'].mean(), df_clean2['Age_19_Under'].mean(), 
                 df_clean2['Age_19_64'].mean(),df_clean2['Age_65_84'].mean(),df_clean2['Age_85_and_Over'].mean(),
                 df_clean2['Pap_Smear'].mean(),df_clean2['Mammogram'].mean(),df_clean2['Proctoscopy'].mean(),
                 df_clean2['Pneumo_Vax'].mean(),df_clean2['Flu_Vac'].mean(),df_clean2['LBW'].mean(),
                 df_clean2['Premature'].mean(), df_clean2['Late_Care'].mean(),df_clean2['Infant_Mortality'].mean(),
                 df_clean2['Brst_Cancer'].mean(),df_clean2['Col_Cancer'].mean(),df_clean2['CHD'].mean(),
                 df_clean2['Lung_Cancer'].mean(),df_clean2['Stroke'].mean(),df_clean2['Obesity'].mean(),
                 df_clean2['High_Blood_Pres'].mean(),df_clean2['Diabetes'].mean(),df_clean2['Uninsured'].mean(),
                 df_clean2['Elderly_Medicare'].mean(),df_clean2['Disabled_Medicare'].mean(),
                 df_clean2['Prim_Care_Phys_Rate'].mean(),df_clean2['Dentist_Rate'].mean(),
                 df_clean2['Community_Health_Center_Ind'].mean()], 
     'cluster3':[sortcounties[sortcounties['cluster']== 2]['State_FIPS_Code'].count(), df_clean3['Population_Size'].mean(), df_clean3['Poverty'].mean(), df_clean3['Age_19_Under'].mean(), 
                 df_clean3['Age_19_64'].mean(),df_clean3['Age_65_84'].mean(),df_clean3['Age_85_and_Over'].mean(),
                 df_clean3['Pap_Smear'].mean(),df_clean3['Mammogram'].mean(),df_clean3['Proctoscopy'].mean(),
                 df_clean3['Pneumo_Vax'].mean(),df_clean3['Flu_Vac'].mean(),df_clean3['LBW'].mean(),
                 df_clean3['Premature'].mean(), df_clean3['Late_Care'].mean(),df_clean3['Infant_Mortality'].mean(),
                 df_clean3['Brst_Cancer'].mean(),df_clean3['Col_Cancer'].mean(),df_clean3['CHD'].mean(),
                 df_clean3['Lung_Cancer'].mean(),df_clean3['Stroke'].mean(),df_clean3['Obesity'].mean(),
                 df_clean3['High_Blood_Pres'].mean(),df_clean3['Diabetes'].mean(),df_clean3['Uninsured'].mean(),
                 df_clean3['Elderly_Medicare'].mean(),df_clean3['Disabled_Medicare'].mean(),
                 df_clean3['Prim_Care_Phys_Rate'].mean(),df_clean3['Dentist_Rate'].mean(),
                 df_clean3['Community_Health_Center_Ind'].mean()], 
     'cluster4':[sortcounties[sortcounties['cluster']== 3]['State_FIPS_Code'].count(), df_clean4['Population_Size'].mean(), df_clean4['Poverty'].mean(), df_clean4['Age_19_Under'].mean(), 
                 df_clean4['Age_19_64'].mean(),df_clean4['Age_65_84'].mean(),df_clean4['Age_85_and_Over'].mean(),
                 df_clean4['Pap_Smear'].mean(),df_clean4['Mammogram'].mean(),df_clean4['Proctoscopy'].mean(),
                 df_clean4['Pneumo_Vax'].mean(),df_clean4['Flu_Vac'].mean(),df_clean4['LBW'].mean(),
                 df_clean4['Premature'].mean(), df_clean4['Late_Care'].mean(),df_clean4['Infant_Mortality'].mean(),
                 df_clean4['Brst_Cancer'].mean(),df_clean4['Col_Cancer'].mean(),df_clean4['CHD'].mean(),
                 df_clean4['Lung_Cancer'].mean(),df_clean4['Stroke'].mean(),df_clean4['Obesity'].mean(),
                 df_clean4['High_Blood_Pres'].mean(),df_clean4['Diabetes'].mean(),df_clean4['Uninsured'].mean(),
                 df_clean4['Elderly_Medicare'].mean(),df_clean4['Disabled_Medicare'].mean(),
                 df_clean4['Prim_Care_Phys_Rate'].mean(),df_clean4['Dentist_Rate'].mean(),
                 df_clean4['Community_Health_Center_Ind'].mean()]}

mean_df= pd.DataFrame(data= d0)

print("These are the means of each feature for the different clusters:")

mean_df
# Out:
# These are the means of each feature for the different clusters:
#                        features      cluster1      cluster2       cluster3  \
# 0               Num of counties    614.000000    735.000000     797.000000
# 1               Population_Size  78163.949511  34656.787755  230899.061481
# 2                       Poverty     18.239251     15.757415      11.516813
# 3                  Age_19_Under     25.848697     25.297415      24.912547
# 4                     Age_19_64     60.180456     60.362857      61.081681
# 5                     Age_65_84     12.226384     12.543810      12.020201
# 6               Age_85_and_Over      1.746417      1.797007       1.985445
# 7                     Pap_Smear     82.027409     81.692959      82.011879
# 8                     Mammogram     79.699498     79.559994      80.534527
# 9                   Proctoscopy     42.256104     42.080275      44.665618
# 10                   Pneumo_Vax     64.847164     65.497752      65.878336
# 11                      Flu_Vac     68.377688     69.330247      69.677271
# 12                          LBW      9.372476      8.390363       6.939833
# 13                    Premature     14.363518     12.963445      10.920116
# 14                    Late_Care     20.798300     19.087039      16.870121
# 15             Infant_Mortality      9.380538      8.216042       6.496288
# 16                  Brst_Cancer     27.644440     26.286727      25.259871
# 17                   Col_Cancer     22.170565     22.190325      20.129422
# 18                          CHD    216.610423    217.674375     171.641070
# 19                  Lung_Cancer     66.964462     67.808214      54.345091
# 20                       Stroke     69.901084     70.109394      58.036783
# 21                      Obesity     26.522427     25.590640      22.531708
# 22              High_Blood_Pres     28.196026     27.465976      25.380365
# 23                     Diabetes      9.383871      8.708358       7.025200
# 24                    Uninsured  12613.682444   4888.945578   30851.426600
# 25             Elderly_Medicare   9250.332248   4434.664464   25849.394109
# 26            Disabled_Medicare   2172.407166    990.972378    4019.909409
# 27          Prim_Care_Phys_Rate     52.063844     45.870748      71.557340
# 28                 Dentist_Rate     25.968404     25.353469      39.738018
# 29  Community_Health_Center_Ind      1.000000      2.000000       1.000000
#
#         cluster4
# 0     995.000000
# 1   39114.018090
# 2      10.023467
# 3      23.715879
# 4      59.667739
# 5      13.934472
# 6       2.682412
# 7      82.230561
# 8      80.185061
# 9      43.263126
# 10     65.685556
# 11     69.962900
# 12      6.354662
# 13     10.307790
# 14     15.716416
# 15      6.330568
# 16     26.392985
# 17     21.215961
# 18    171.208507
# 19     50.170304
# 20     58.691702
# 21     22.902890
# 22     25.576532
# 23      6.804397
# 24   3854.492503
# 25   5064.308620
# 26    706.755671
# 27     58.382211
# 28     34.953834
# 29      2.000000

# %%
#infant mortality vs late care plot. This is only to try and visualize the clusters
sns.lmplot(x='Late_Care',y='Infant_Mortality',data=df_clean,hue='cluster',fit_reg=False)
plt.title('Late care vs. infant mortality for the different clusters', size= 18)
plt.show()

# %%
#radar chart
#Main source: https://python-graph-gallery.com/392-use-faceting-for-radar-chart/

# Set data
df = pd.DataFrame({
'group': ['Cluster1','Cluster2','Cluster3','Cluster4'],
'Poverty': [df_clean1['Poverty'].mean(), df_clean2['Poverty'].mean(), df_clean3['Poverty'].mean(), df_clean4['Poverty'].mean()],
'PCPsNo': [df_clean1['Prim_Care_Phys_Rate'].mean(), df_clean2['Prim_Care_Phys_Rate'].mean(), df_clean3['Prim_Care_Phys_Rate'].mean(), df_clean4['Prim_Care_Phys_Rate'].mean()],
'Obesity': [df_clean1['Obesity'].mean(), df_clean2['Obesity'].mean(), df_clean3['Obesity'].mean(), df_clean4['Obesity'].mean()],
'High_Blood_Pres': [df_clean1['High_Blood_Pres'].mean(), df_clean2['High_Blood_Pres'].mean(), df_clean3['High_Blood_Pres'].mean(), df_clean4['High_Blood_Pres'].mean()],
'Inft_mor': [df_clean1['Infant_Mortality'].mean(), df_clean2['Infant_Mortality'].mean(), df_clean3['Infant_Mortality'].mean(), df_clean4['Infant_Mortality'].mean()]
})
# ------- PART 1: Define a function that do a plot for one line of the dataset!
 
def make_spider( row, title, color):
 
    # number of variable
    categories=list(df)[1:]
    N = len(categories)

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(2,2,row+1, polar=True, )

    # If you want the first axis to be on top:
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)

    # Draw ylabels
    ax.set_rlabel_position(0)
    plt.yticks([20,30,40, 60, 80, 100], ["20","40","60", "80", "100"], color="grey", size=7)
    plt.ylim(0,75)

    # Ind1
    values=df.loc[row].drop('group').values.flatten().tolist()
    values += values[:1]
    ax.plot(angles, values, color=color, linewidth=2, linestyle='solid')
    ax.fill(angles, values, color=color, alpha=0.4)

    # Add a title
    plt.title(title, size=11, color=color, y=1.1)

# ------- PART 2: Apply to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title='group '+df['group'][row], color=my_palette(row))
    
#plt.savefig('KMEANSradar.pdf')
    
print('Radar chart using K-means that shows the difference in features for the different clusters')
# Out:
# Radar chart using K-means that shows the difference in features for the different clusters

# %% [markdown]
# ## K-means performed with PCA
# ### PCA is used for dimentionality reduction.

# %%
from sklearn.decomposition import KernelPCA

#build the model and apply it on dataset to reduce dimensions 
Kpca = KernelPCA(n_components=2, kernel='rbf')
Transformed_X= Kpca.fit_transform(X)

#perform k-means
KPCAy_pred= kmeans.fit_predict(Transformed_X)
KPCAy_pred
# Out:
# array([0, 2, 0, ..., 1, 2, 1], dtype=int32)

# %%
#K-means with PCA silhouette coefficient score
metrics.silhouette_score(X, KPCAy_pred, metric='euclidean')
# Out:
# 0.1650593077617572

# %%
#filter rows of original data
filtered_label0 = Transformed_X[KPCAy_pred == 0]
filtered_label1 = Transformed_X[KPCAy_pred == 1]
filtered_label2 = Transformed_X[KPCAy_pred == 2]
filtered_label3 = Transformed_X[KPCAy_pred == 3]

 
#plotting the results
plt.scatter(filtered_label0[:,0] , filtered_label0[:,1],color = 'blue')
plt.scatter(filtered_label1[:,0] , filtered_label1[:,1],color = 'red')
plt.scatter(filtered_label2[:,0] , filtered_label2[:,1], color = 'orange')
plt.scatter(filtered_label3[:,0] , filtered_label3[:,1], color = 'green')

plt.xlabel('PC1')
plt.ylabel('PC2')
plt.title('County Clusters after performing K-means with PCA')

plt.show()

# %%
#Adding a cluster column and sorting the counties by which cluster they belong to
df_clean['PCAcluster']= KPCAy_pred
pca_sortcounties = df_clean.sort_values(['PCAcluster'])

pca_sortcounties
# Out:
#       State_FIPS_Code  County_FIPS_Code CHSI_County_Name               county  \
# 0                 1.0               1.0          Autauga      Autauga_Alabama
# 1478             28.0             159.0          Winston  Winston_Mississippi
# 1480             28.0             163.0            Yazoo    Yazoo_Mississippi
# 1485             29.0               9.0            Barry       Barry_Missouri
# 1488             29.0              15.0           Benton      Benton_Missouri
# ...               ...               ...              ...                  ...
# 1073             21.0             165.0          Menifee     Menifee_Kentucky
# 114               5.0              11.0          Bradley     Bradley_Arkansas
# 2561             48.0              81.0             Coke           Coke_Texas
# 1074             21.0             167.0           Mercer      Mercer_Kentucky
# 1099             21.0             217.0           Taylor      Taylor_Kentucky
#
#      CHSI_State_Name CHSI_State_Abbr  Population_Size  Poverty  Age_19_Under  \
# 0            Alabama              AL          48612.0     10.4          26.9
# 1478     Mississippi              MS          19870.0     20.0          25.7
# 1480     Mississippi              MS          28195.0     27.0          27.5
# 1485        Missouri              MO          35599.0     14.9          25.5
# 1488        Missouri              MO          18854.0     14.6          19.1
# ...              ...             ...              ...      ...           ...
# 1073        Kentucky              KY           6809.0     22.0          24.0
# 114         Arkansas              AR          12192.0     20.3          23.4
# 2561           Texas              TX           3612.0     14.8          24.9
# 1074        Kentucky              KY          21610.0     12.7          24.4
# 1099        Kentucky              KY          23754.0     16.6          23.6
#
#       Age_19_64  Age_65_84  Age_85_and_Over   ALE  Pap_Smear  Mammogram  \
# 0          62.3        9.8              0.9  74.9  82.009561   80.03255
# 1478       58.5       13.8              2.0  75.3  82.500000   80.03255
# 1480       60.7       10.2              1.6  72.3  75.500000   82.50000
# 1485       58.7       14.0              1.8  75.3  82.009561   80.03255
# 1488       57.9       20.8              2.2  75.3  82.009561   80.03255
# ...         ...        ...              ...   ...        ...        ...
# 1073       62.3       12.7              1.0  72.6  84.700000   80.03255
# 114        59.5       14.9              2.2  73.3  80.600000   80.03255
# 2561       50.6       21.6              2.9  76.0  82.009561   80.03255
# 1074       61.2       12.7              1.8  76.1  82.009561   80.03255
# 1099       60.1       14.5              1.8  75.4  81.100000   82.00000
#
#       Proctoscopy  Pneumo_Vax    Flu_Vac   LBW  Premature  Late_Care  \
# 0       43.145354   65.526638  69.432507   8.1       14.3       12.9
# 1478    43.145354   65.526638  69.432507   9.8       14.8       27.0
# 1480    43.145354   65.526638  69.432507  13.1       20.4       18.4
# 1485    43.145354   65.526638  69.432507   7.7       13.3       17.9
# 1488    43.145354   65.526638  69.432507   6.7        9.8       13.8
# ...           ...         ...        ...   ...        ...        ...
# 1073    43.145354   65.526638  69.432507   8.7       11.7       20.1
# 114     43.145354   65.526638  69.432507   9.0       12.6       26.1
# 2561    43.145354   65.526638  69.432507   5.2       12.7       33.4
# 1074    43.145354   65.526638  69.432507   9.4       13.3       16.2
# 1099    29.000000   65.526638  69.432507   6.5       10.7       12.5
#
#       Infant_Mortality  Brst_Cancer  Col_Cancer    CHD  Lung_Cancer  Stroke  \
# 0             5.900000    34.100000        15.9  172.4         65.3    73.9
# 1478          9.700000    30.200000        19.4  146.7         64.8    73.3
# 1480         12.800000    39.100000        15.2  213.7         71.0    83.8
# 1485          6.200000    20.300000        18.2  252.4         67.1    77.8
# 1488          8.600000    33.300000        30.6  194.4         92.4    63.3
# ...                ...          ...         ...    ...          ...     ...
# 1073          7.100000    29.100000        27.7  185.8         71.9    61.2
# 114           6.600000    22.400000        20.4  279.4         71.2   112.1
# 2561          7.410028    26.325236        21.5  190.6         67.0    45.3
# 1074          7.400000    25.300000        22.1  183.2         74.0    65.4
# 1099          6.700000    24.200000        29.3  198.3         69.7    72.4
#
#       Total_Deaths    Obesity  High_Blood_Pres   Diabetes  Uninsured  \
# 0           1867.0  24.500000        29.100000  14.200000     5690.0
# 1478        2235.0  38.900000        26.480946   9.500000     3244.0
# 1480        1535.0  33.600000        26.480946   9.700000     6373.0
# 1485        1932.0  26.800000        26.480946  11.500000     6158.0
# 1488        2425.0  24.600000        26.480946  17.800000     2788.0
# ...            ...        ...              ...        ...        ...
# 1073         592.0  25.100000        31.400000  10.800000     1252.0
# 114         1778.0  25.200000        26.480946   8.500000     2467.0
# 2561         607.0  24.145189        26.480946   7.810188      645.0
# 1074        2223.0  27.900000        26.480946   8.400000     2681.0
# 1099        2458.0  18.800000        33.200000   6.800000     3253.0
#
#       Elderly_Medicare  Disabled_Medicare  Prim_Care_Phys_Rate  Dentist_Rate  \
# 0               4762.0             1209.0                 45.3          22.6
# 1478            2797.0              682.0                 25.2          20.1
# 1480            3297.0              891.0                 21.3          21.3
# 1485            5828.0             1128.0                 61.8          22.5
# 1488            4030.0              899.0                 10.6          15.9
# ...                ...                ...                  ...           ...
# 1073             781.0              372.0                  0.0          29.4
# 114             1945.0              469.0                 73.8          24.6
# 2561             715.0               62.0                  0.0           0.0
# 1074            3096.0              673.0                 46.3          23.1
# 1099            3656.0             1279.0                 88.4          50.5
#
#       Community_Health_Center_Ind  Uninsured%  cluster  PCAcluster
# 0                             1.0   11.704929        0           0
# 1478                          1.0   16.326120        0           0
# 1480                          1.0   22.603298        0           0
# 1485                          1.0   17.298239        0           0
# 1488                          1.0   14.787313        0           0
# ...                           ...         ...      ...         ...
# 1073                          2.0   18.387428        1           3
# 114                           2.0   20.234580        1           3
# 2561                          2.0   17.857143        3           3
# 1074                          2.0   12.406293        1           3
# 1099                          2.0   13.694536        1           3
#
# [3141 rows x 40 columns]

# %%
#creating a dataframe with all the means of each feature in each cluster
df_clean1=df_clean[df_clean['PCAcluster']== 0]
df_clean2=df_clean[df_clean['PCAcluster']== 1]
df_clean3=df_clean[df_clean['PCAcluster']== 2]
df_clean4=df_clean[df_clean['PCAcluster']== 3]

d0= {'features':['Num of counties','Population_Size', 'Poverty', 'Age_19_Under', 'Age_19_64', 'Age_65_84',
       'Age_85_and_Over', 'Pap_Smear', 'Mammogram', 'Proctoscopy',
       'Pneumo_Vax', 'Flu_Vac', 'LBW', 'Premature', 'Late_Care',
       'Infant_Mortality', 'Brst_Cancer', 'Col_Cancer', 'CHD', 'Lung_Cancer',
       'Stroke', 'Obesity', 'High_Blood_Pres', 'Diabetes', 'Uninsured',
       'Elderly_Medicare', 'Disabled_Medicare', 'Prim_Care_Phys_Rate',
       'Dentist_Rate', 'Community_Health_Center_Ind'],
     'cluster1':[sortcounties[sortcounties['cluster']== 0]['State_FIPS_Code'].count(), df_clean1['Population_Size'].mean(), df_clean1['Poverty'].mean(), 
                 df_clean1['Age_19_Under'].mean(), df_clean1['Age_19_64'].mean(),
                 df_clean1['Age_65_84'].mean(),df_clean1['Age_85_and_Over'].mean(),
                 df_clean1['Pap_Smear'].mean(),df_clean1['Mammogram'].mean(),df_clean1['Proctoscopy'].mean(),
                 df_clean1['Pneumo_Vax'].mean(),df_clean1['Flu_Vac'].mean(),df_clean1['LBW'].mean(),
                 df_clean1['Premature'].mean(), df_clean1['Late_Care'].mean(),df_clean1['Infant_Mortality'].mean(),
                 df_clean1['Brst_Cancer'].mean(),df_clean1['Col_Cancer'].mean(),df_clean1['CHD'].mean(),
                 df_clean1['Lung_Cancer'].mean(),df_clean1['Stroke'].mean(),df_clean1['Obesity'].mean(),
                 df_clean1['High_Blood_Pres'].mean(),df_clean1['Diabetes'].mean(),df_clean1['Uninsured'].mean(),
                 df_clean1['Elderly_Medicare'].mean(),df_clean1['Disabled_Medicare'].mean(),
                 df_clean1['Prim_Care_Phys_Rate'].mean(),df_clean1['Dentist_Rate'].mean(),
                 df_clean1['Community_Health_Center_Ind'].mean()], 
     'cluster2':[sortcounties[sortcounties['cluster']== 1]['State_FIPS_Code'].count(), df_clean2['Population_Size'].mean(), df_clean2['Poverty'].mean(), df_clean2['Age_19_Under'].mean(), 
                 df_clean2['Age_19_64'].mean(),df_clean2['Age_65_84'].mean(),df_clean2['Age_85_and_Over'].mean(),
                 df_clean2['Pap_Smear'].mean(),df_clean2['Mammogram'].mean(),df_clean2['Proctoscopy'].mean(),
                 df_clean2['Pneumo_Vax'].mean(),df_clean2['Flu_Vac'].mean(),df_clean2['LBW'].mean(),
                 df_clean2['Premature'].mean(), df_clean2['Late_Care'].mean(),df_clean2['Infant_Mortality'].mean(),
                 df_clean2['Brst_Cancer'].mean(),df_clean2['Col_Cancer'].mean(),df_clean2['CHD'].mean(),
                 df_clean2['Lung_Cancer'].mean(),df_clean2['Stroke'].mean(),df_clean2['Obesity'].mean(),
                 df_clean2['High_Blood_Pres'].mean(),df_clean2['Diabetes'].mean(),df_clean2['Uninsured'].mean(),
                 df_clean2['Elderly_Medicare'].mean(),df_clean2['Disabled_Medicare'].mean(),
                 df_clean2['Prim_Care_Phys_Rate'].mean(),df_clean2['Dentist_Rate'].mean(),
                 df_clean2['Community_Health_Center_Ind'].mean()], 
     'cluster3':[sortcounties[sortcounties['cluster']== 2]['State_FIPS_Code'].count(), df_clean3['Population_Size'].mean(), df_clean3['Poverty'].mean(), df_clean3['Age_19_Under'].mean(), 
                 df_clean3['Age_19_64'].mean(),df_clean3['Age_65_84'].mean(),df_clean3['Age_85_and_Over'].mean(),
                 df_clean3['Pap_Smear'].mean(),df_clean3['Mammogram'].mean(),df_clean3['Proctoscopy'].mean(),
                 df_clean3['Pneumo_Vax'].mean(),df_clean3['Flu_Vac'].mean(),df_clean3['LBW'].mean(),
                 df_clean3['Premature'].mean(), df_clean3['Late_Care'].mean(),df_clean3['Infant_Mortality'].mean(),
                 df_clean3['Brst_Cancer'].mean(),df_clean3['Col_Cancer'].mean(),df_clean3['CHD'].mean(),
                 df_clean3['Lung_Cancer'].mean(),df_clean3['Stroke'].mean(),df_clean3['Obesity'].mean(),
                 df_clean3['High_Blood_Pres'].mean(),df_clean3['Diabetes'].mean(),df_clean3['Uninsured'].mean(),
                 df_clean3['Elderly_Medicare'].mean(),df_clean3['Disabled_Medicare'].mean(),
                 df_clean3['Prim_Care_Phys_Rate'].mean(),df_clean3['Dentist_Rate'].mean(),
                 df_clean3['Community_Health_Center_Ind'].mean()], 
     'cluster4':[sortcounties[sortcounties['cluster']== 3]['State_FIPS_Code'].count(), df_clean4['Population_Size'].mean(), df_clean4['Poverty'].mean(), df_clean4['Age_19_Under'].mean(), 
                 df_clean4['Age_19_64'].mean(),df_clean4['Age_65_84'].mean(),df_clean4['Age_85_and_Over'].mean(),
                 df_clean4['Pap_Smear'].mean(),df_clean4['Mammogram'].mean(),df_clean4['Proctoscopy'].mean(),
                 df_clean4['Pneumo_Vax'].mean(),df_clean4['Flu_Vac'].mean(),df_clean4['LBW'].mean(),
                 df_clean4['Premature'].mean(), df_clean4['Late_Care'].mean(),df_clean4['Infant_Mortality'].mean(),
                 df_clean4['Brst_Cancer'].mean(),df_clean4['Col_Cancer'].mean(),df_clean4['CHD'].mean(),
                 df_clean4['Lung_Cancer'].mean(),df_clean4['Stroke'].mean(),df_clean4['Obesity'].mean(),
                 df_clean4['High_Blood_Pres'].mean(),df_clean4['Diabetes'].mean(),df_clean4['Uninsured'].mean(),
                 df_clean4['Elderly_Medicare'].mean(),df_clean4['Disabled_Medicare'].mean(),
                 df_clean4['Prim_Care_Phys_Rate'].mean(),df_clean4['Dentist_Rate'].mean(),
                 df_clean4['Community_Health_Center_Ind'].mean()]}

mean_df= pd.DataFrame(data= d0)

print("These are the means of each feature for the different clusters:")


mean_df
# Out:
# These are the means of each feature for the different clusters:
#                        features      cluster1      cluster2       cluster3  \
# 0               Num of counties    614.000000    735.000000     797.000000
# 1               Population_Size  78748.180328  40616.625709  229691.419476
# 2                       Poverty     18.231311     10.068384      11.556429
# 3                  Age_19_Under     25.845902     23.912665      24.919351
# 4                     Age_19_64     60.214426     59.912760      61.051311
# 5                     Age_65_84     12.199344     13.606994      12.041823
# 6               Age_85_and_Over      1.742459      2.567675       1.987266
# 7                     Pap_Smear     81.969376     82.294653      82.056151
# 8                     Mammogram     79.703487     80.152829      80.527319
# 9                   Proctoscopy     42.294445     43.262678      44.624386
# 10                   Pneumo_Vax     64.871561     65.669465      65.854607
# 11                      Flu_Vac     68.389788     69.925525      69.661567
# 12                          LBW      9.373607      6.414298       6.951120
# 13                    Premature     14.356885     10.383624      10.942362
# 14                    Late_Care     20.754027     15.731121      16.923454
# 15             Infant_Mortality      9.396443      6.327112       6.498578
# 16                  Brst_Cancer     27.621984     26.192198      25.288880
# 17                   Col_Cancer     22.194216     21.148436      20.121604
# 18                          CHD    217.291148    172.111466     171.347232
# 19                  Lung_Cancer     67.126688     50.927157      54.284566
# 20                       Stroke     70.058304     59.140284      57.976299
# 21                      Obesity     26.538582     22.958908      22.539335
# 22              High_Blood_Pres     28.237178     25.530116      25.363086
# 23                     Diabetes      9.388141      6.831424       7.033727
# 24                    Uninsured  12690.327902   4069.164500   30701.982522
# 25             Elderly_Medicare   9323.798361   5177.622523   25710.554438
# 26            Disabled_Medicare   2190.549180    749.569226    3996.867414
# 27          Prim_Care_Phys_Rate     52.035574     57.074858      71.481523
# 28                 Dentist_Rate     25.929508     34.139853      39.698876
# 29  Community_Health_Center_Ind      1.000000      2.000000       1.000000
#
#         cluster4
# 0     995.000000
# 1   31873.209821
# 2      16.224256
# 3      25.135863
# 4      60.042262
# 5      12.929018
# 6       1.894643
# 7      81.541652
# 8      79.552139
# 9      41.970087
# 10     65.505480
# 11     69.329779
# 12      8.487318
# 13     13.093020
# 14     19.379885
# 15      8.398246
# 16     26.592885
# 17     22.387982
# 18    220.608928
# 19     68.270175
# 20     70.473552
# 21     25.754422
# 22     27.716188
# 23      8.844303
# 24   4647.944940
# 25   4197.233376
# 26    950.211829
# 27     46.756101
# 28     25.734970
# 29      2.000000

# %%
#radar chart
#Main source: https://python-graph-gallery.com/392-use-faceting-for-radar-chart/

# Set data
df = pd.DataFrame({
'group': ['Cluster1','Cluster2','Cluster3','Cluster4'],
'Poverty': [df_clean1['Poverty'].mean(), df_clean2['Poverty'].mean(), df_clean3['Poverty'].mean(), df_clean4['Poverty'].mean()],
'PCPsNo': [df_clean1['Prim_Care_Phys_Rate'].mean(), df_clean2['Prim_Care_Phys_Rate'].mean(), df_clean3['Prim_Care_Phys_Rate'].mean(), df_clean4['Prim_Care_Phys_Rate'].mean()],
'Obesity': [df_clean1['Obesity'].mean(), df_clean2['Obesity'].mean(), df_clean3['Obesity'].mean(), df_clean4['Obesity'].mean()],
'High_Blood_Pres': [df_clean1['High_Blood_Pres'].mean(), df_clean2['High_Blood_Pres'].mean(), df_clean3['High_Blood_Pres'].mean(), df_clean4['High_Blood_Pres'].mean()],
'Inft_mor': [df_clean1['Infant_Mortality'].mean(), df_clean2['Infant_Mortality'].mean(), df_clean3['Infant_Mortality'].mean(), df_clean4['Infant_Mortality'].mean()]
}) 

# ------- PART 2: Apply to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title='group '+df['group'][row], color=my_palette(row))

    
#plt.savefig('PCAradar.pdf')

print('Radar chart using PCA/K-means that shows the difference in features for the different clusters')
# Out:
# Radar chart using PCA/K-means that shows the difference in features for the different clusters

# %% [markdown]
# ### PAM- Partition Around Medoids

# %%
# !pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in /Users/ghitamoummi/opt/anaconda3/lib/python3.7/site-packages (0.1.0b2)
# Requirement already satisfied: scipy>=0.19.1 in /Users/ghitamoummi/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn-extra) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.21.0 in /Users/ghitamoummi/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn-extra) (0.22.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/ghitamoummi/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn-extra) (1.18.1)
# Requirement already satisfied: joblib>=0.11 in /Users/ghitamoummi/opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.21.0->scikit-learn-extra) (0.14.1)

# %%
from sklearn_extra.cluster import KMedoids

#build model, apply it on dataset and predict labels
kmedoids = KMedoids(n_clusters=4, random_state=10).fit(X)
kmedoids.labels_

medoid_pred= kmedoids.predict(X)

# %%
#PAM silhouette coefficient score
metrics.silhouette_score(X, medoid_pred, metric='euclidean')
# Out:
# 0.21596663557284848

# %%
#Adding a cluster column and sorting the counties by which cluster they belong to
df_clean['MedoidClusters']= medoid_pred
medoid_sortcounties = df_clean.sort_values(['MedoidClusters'])

medoid_sortcounties
# Out:
#       State_FIPS_Code  County_FIPS_Code CHSI_County_Name              county  \
# 871              19.0             169.0            Story          Story_Iowa
# 877              19.0             181.0           Warren         Warren_Iowa
# 878              19.0             183.0       Washington     Washington_Iowa
# 881              19.0             189.0        Winnebago      Winnebago_Iowa
# 882              19.0             191.0       Winneshiek     Winneshiek_Iowa
# ...               ...               ...              ...                 ...
# 768              18.0             147.0          Spencer     Spencer_Indiana
# 767              18.0             145.0           Shelby      Shelby_Indiana
# 764              18.0             139.0             Rush        Rush_Indiana
# 782              18.0             175.0       Washington  Washington_Indiana
# 3140             56.0              45.0           Weston      Weston_Wyoming
#
#      CHSI_State_Name CHSI_State_Abbr  Population_Size  Poverty  Age_19_Under  \
# 871             Iowa              IA          79952.0      9.8          21.0
# 877             Iowa              IA          42981.0      6.0          24.5
# 878             Iowa              IA          21457.0      7.7          24.7
# 881             Iowa              IA          11351.0      8.3          23.0
# 882             Iowa              IA          21234.0      7.8          22.4
# ...              ...             ...              ...      ...           ...
# 768          Indiana              IN          20528.0      7.6          25.5
# 767          Indiana              IN          43766.0      8.5          26.2
# 764          Indiana              IN          17823.0      8.6          27.3
# 782          Indiana              IN          27885.0     10.5          26.1
# 3140         Wyoming              WY           6671.0      9.9          20.1
#
#       Age_19_64  Age_65_84  Age_85_and_Over   ALE  Pap_Smear  Mammogram  \
# 871        68.5        8.6              1.9  81.0  86.200000   84.80000
# 877        63.2       10.7              1.6  78.8  84.900000   74.30000
# 878        58.3       13.8              3.2  79.6  79.500000   80.03255
# 881        58.4       14.6              4.0  78.9  85.400000   80.03255
# 882        61.7       12.9              3.1  80.8  82.100000   80.03255
# ...         ...        ...              ...   ...        ...        ...
# 768        60.9       12.0              1.6  76.9  82.009561   80.03255
# 767        61.2       10.8              1.7  76.3  80.500000   80.03255
# 764        57.8       12.6              2.3  77.1  82.009561   80.03255
# 782        61.6       10.7              1.6  75.0  82.009561   80.03255
# 3140       63.2       14.4              2.4  77.4  75.500000   67.00000
#
#       Proctoscopy  Pneumo_Vax    Flu_Vac  LBW  Premature  Late_Care  \
# 871     62.800000   71.900000  79.800000  5.3        8.4        6.5
# 877     39.800000   71.800000  75.300000  5.9       11.3        6.6
# 878     43.145354   65.526638  69.432507  5.6        9.1       15.9
# 881     43.145354   65.526638  69.432507  6.4       10.1       17.3
# 882     43.145354   65.526638  69.432507  5.0        8.2       14.0
# ...           ...         ...        ...  ...        ...        ...
# 768     43.145354   65.526638  69.432507  7.5       13.1       13.2
# 767     43.145354   65.526638  69.432507  7.6       12.2       16.6
# 764     43.145354   65.526638  69.432507  7.0       11.0       17.1
# 782     43.145354   65.526638  69.432507  6.5       11.9       19.6
# 3140    39.500000   77.300000  75.300000  8.8       10.7       18.9
#
#       Infant_Mortality  Brst_Cancer  Col_Cancer    CHD  Lung_Cancer  Stroke  \
# 871                4.4    20.000000        19.6  144.9         40.0    51.3
# 877                7.2    31.900000        19.3  182.3         41.7    71.8
# 878                7.3    20.400000        25.2  183.7         32.3    47.7
# 881                5.2    28.600000        16.5  194.7         37.2    70.7
# 882                3.8    19.400000        26.1  149.8         38.3    51.1
# ...                ...          ...         ...    ...          ...     ...
# 768                6.7    22.800000        16.0  202.6         57.5    70.6
# 767                8.9    28.200000        16.2  173.6         66.8    55.2
# 764                3.1    23.200000        21.1  208.8         70.3    53.3
# 782                3.4    21.600000        17.6  240.8         69.2    63.6
# 3140              11.7    26.325236        32.8  126.0         58.9    47.2
#
#       Total_Deaths  Obesity  High_Blood_Pres  Diabetes  Uninsured  \
# 871         2328.0     17.2        15.500000       4.5     5642.0
# 877         1677.0     26.0        26.800000       6.1     2789.0
# 878         2321.0     25.3        23.400000       4.2     2006.0
# 881         1418.0     25.6        23.800000       7.7      905.0
# 882         1842.0     19.5        19.200000       4.6     1287.0
# ...            ...      ...              ...       ...        ...
# 768         1816.0     24.9        26.480946       5.0     2131.0
# 767         1909.0     31.1        26.480946       6.5     3912.0
# 764         1914.0     29.3        26.480946       4.3     1584.0
# 782         1302.0     23.9        26.480946       7.1     2751.0
# 3140         629.0     24.2        26.700000       5.7      867.0
#
#       Elderly_Medicare  Disabled_Medicare  Prim_Care_Phys_Rate  Dentist_Rate  \
# 871             8169.0              851.0                 75.0          37.5
# 877             4561.0              619.0                 16.3          25.6
# 878             3710.0              376.0                 46.6          37.3
# 881             2270.0              197.0                 35.2          61.7
# 882             3182.0              278.0                 75.4          47.1
# ...                ...                ...                  ...           ...
# 768             2708.0              433.0                 29.2          19.5
# 767             5032.0              810.0                 45.7          27.4
# 764             2545.0              362.0                 50.5          16.8
# 782             3078.0              858.0                 43.0          17.9
# 3140            1072.0              143.0                 45.0          30.0
#
#       Community_Health_Center_Ind  Uninsured%  cluster  PCAcluster  \
# 871                           2.0    7.056734        3           1
# 877                           2.0    6.488914        3           1
# 878                           2.0    9.348930        3           1
# 881                           2.0    7.972866        3           1
# 882                           2.0    6.061034        3           1
# ...                           ...         ...      ...         ...
# 768                           2.0   10.380943        3           1
# 767                           2.0    8.938445        1           1
# 764                           2.0    8.887393        3           1
# 782                           2.0    9.865519        1           1
# 3140                          2.0   12.996552        3           1
#
#       MedoidClusters
# 871                0
# 877                0
# 878                0
# 881                0
# 882                0
# ...              ...
# 768                3
# 767                3
# 764                3
# 782                3
# 3140               3
#
# [3141 rows x 41 columns]

# %%
#export data for Tableau
medoid_sortcounties.to_csv('clusteredcounties.csv')

# %%
#creating a dataframe with all the means of each feature in each cluster
df_clean1=df_clean[df_clean['MedoidClusters']== 0]
df_clean2=df_clean[df_clean['MedoidClusters']== 1]
df_clean3=df_clean[df_clean['MedoidClusters']== 2]
df_clean4=df_clean[df_clean['MedoidClusters']== 3]

d0= {'features':['Num of counties','Population_Size', 'Poverty', 'Age_19_Under', 'Age_19_64', 'Age_65_84',
       'Age_85_and_Over', 'Pap_Smear', 'Mammogram', 'Proctoscopy',
       'Pneumo_Vax', 'Flu_Vac', 'LBW', 'Premature', 'Late_Care',
       'Infant_Mortality', 'Brst_Cancer', 'Col_Cancer', 'CHD', 'Lung_Cancer',
       'Stroke', 'Obesity', 'High_Blood_Pres', 'Diabetes', 'Uninsured',
       'Elderly_Medicare', 'Disabled_Medicare', 'Prim_Care_Phys_Rate',
       'Dentist_Rate', 'Community_Health_Center_Ind'],
     'cluster1':[sortcounties[sortcounties['cluster']== 0]['State_FIPS_Code'].count(), df_clean1['Population_Size'].mean(), df_clean1['Poverty'].mean(), 
                 df_clean1['Age_19_Under'].mean(), df_clean1['Age_19_64'].mean(),
                 df_clean1['Age_65_84'].mean(),df_clean1['Age_85_and_Over'].mean(),
                 df_clean1['Pap_Smear'].mean(),df_clean1['Mammogram'].mean(),df_clean1['Proctoscopy'].mean(),
                 df_clean1['Pneumo_Vax'].mean(),df_clean1['Flu_Vac'].mean(),df_clean1['LBW'].mean(),
                 df_clean1['Premature'].mean(), df_clean1['Late_Care'].mean(),df_clean1['Infant_Mortality'].mean(),
                 df_clean1['Brst_Cancer'].mean(),df_clean1['Col_Cancer'].mean(),df_clean1['CHD'].mean(),
                 df_clean1['Lung_Cancer'].mean(),df_clean1['Stroke'].mean(),df_clean1['Obesity'].mean(),
                 df_clean1['High_Blood_Pres'].mean(),df_clean1['Diabetes'].mean(),df_clean1['Uninsured'].mean(),
                 df_clean1['Elderly_Medicare'].mean(),df_clean1['Disabled_Medicare'].mean(),
                 df_clean1['Prim_Care_Phys_Rate'].mean(),df_clean1['Dentist_Rate'].mean(),
                 df_clean1['Community_Health_Center_Ind'].mean()], 
     'cluster2':[sortcounties[sortcounties['cluster']== 1]['State_FIPS_Code'].count(), df_clean2['Population_Size'].mean(), df_clean2['Poverty'].mean(), df_clean2['Age_19_Under'].mean(), 
                 df_clean2['Age_19_64'].mean(),df_clean2['Age_65_84'].mean(),df_clean2['Age_85_and_Over'].mean(),
                 df_clean2['Pap_Smear'].mean(),df_clean2['Mammogram'].mean(),df_clean2['Proctoscopy'].mean(),
                 df_clean2['Pneumo_Vax'].mean(),df_clean2['Flu_Vac'].mean(),df_clean2['LBW'].mean(),
                 df_clean2['Premature'].mean(), df_clean2['Late_Care'].mean(),df_clean2['Infant_Mortality'].mean(),
                 df_clean2['Brst_Cancer'].mean(),df_clean2['Col_Cancer'].mean(),df_clean2['CHD'].mean(),
                 df_clean2['Lung_Cancer'].mean(),df_clean2['Stroke'].mean(),df_clean2['Obesity'].mean(),
                 df_clean2['High_Blood_Pres'].mean(),df_clean2['Diabetes'].mean(),df_clean2['Uninsured'].mean(),
                 df_clean2['Elderly_Medicare'].mean(),df_clean2['Disabled_Medicare'].mean(),
                 df_clean2['Prim_Care_Phys_Rate'].mean(),df_clean2['Dentist_Rate'].mean(),
                 df_clean2['Community_Health_Center_Ind'].mean()], 
     'cluster3':[sortcounties[sortcounties['cluster']== 2]['State_FIPS_Code'].count(), df_clean3['Population_Size'].mean(), df_clean3['Poverty'].mean(), df_clean3['Age_19_Under'].mean(), 
                 df_clean3['Age_19_64'].mean(),df_clean3['Age_65_84'].mean(),df_clean3['Age_85_and_Over'].mean(),
                 df_clean3['Pap_Smear'].mean(),df_clean3['Mammogram'].mean(),df_clean3['Proctoscopy'].mean(),
                 df_clean3['Pneumo_Vax'].mean(),df_clean3['Flu_Vac'].mean(),df_clean3['LBW'].mean(),
                 df_clean3['Premature'].mean(), df_clean3['Late_Care'].mean(),df_clean3['Infant_Mortality'].mean(),
                 df_clean3['Brst_Cancer'].mean(),df_clean3['Col_Cancer'].mean(),df_clean3['CHD'].mean(),
                 df_clean3['Lung_Cancer'].mean(),df_clean3['Stroke'].mean(),df_clean3['Obesity'].mean(),
                 df_clean3['High_Blood_Pres'].mean(),df_clean3['Diabetes'].mean(),df_clean3['Uninsured'].mean(),
                 df_clean3['Elderly_Medicare'].mean(),df_clean3['Disabled_Medicare'].mean(),
                 df_clean3['Prim_Care_Phys_Rate'].mean(),df_clean3['Dentist_Rate'].mean(),
                 df_clean3['Community_Health_Center_Ind'].mean()], 
     'cluster4':[sortcounties[sortcounties['cluster']== 3]['State_FIPS_Code'].count(), df_clean4['Population_Size'].mean(), df_clean4['Poverty'].mean(), df_clean4['Age_19_Under'].mean(), 
                 df_clean4['Age_19_64'].mean(),df_clean4['Age_65_84'].mean(),df_clean4['Age_85_and_Over'].mean(),
                 df_clean4['Pap_Smear'].mean(),df_clean4['Mammogram'].mean(),df_clean4['Proctoscopy'].mean(),
                 df_clean4['Pneumo_Vax'].mean(),df_clean4['Flu_Vac'].mean(),df_clean4['LBW'].mean(),
                 df_clean4['Premature'].mean(), df_clean4['Late_Care'].mean(),df_clean4['Infant_Mortality'].mean(),
                 df_clean4['Brst_Cancer'].mean(),df_clean4['Col_Cancer'].mean(),df_clean4['CHD'].mean(),
                 df_clean4['Lung_Cancer'].mean(),df_clean4['Stroke'].mean(),df_clean4['Obesity'].mean(),
                 df_clean4['High_Blood_Pres'].mean(),df_clean4['Diabetes'].mean(),df_clean4['Uninsured'].mean(),
                 df_clean4['Elderly_Medicare'].mean(),df_clean4['Disabled_Medicare'].mean(),
                 df_clean4['Prim_Care_Phys_Rate'].mean(),df_clean4['Dentist_Rate'].mean(),
                 df_clean4['Community_Health_Center_Ind'].mean()]}

mean_df= pd.DataFrame(data= d0)

print("These are the means of each feature for the different clusters:")

mean_df
# Out:
# These are the means of each feature for the different clusters:
#                        features      cluster1      cluster2       cluster3  \
# 0               Num of counties    614.000000    735.000000     797.000000
# 1               Population_Size  26264.363036  33028.423313  164436.014883
# 2                       Poverty     10.431683     17.322699      14.442098
# 3                  Age_19_Under     23.223102     25.336196      25.319915
# 4                     Age_19_64     58.117822     59.998364      60.689511
# 5                     Age_65_84     15.453135     12.826789      12.109922
# 6               Age_85_and_Over      3.206601      1.840082       1.881432
# 7                     Pap_Smear     81.793141     81.514296      82.018637
# 8                     Mammogram     80.189889     79.485312      80.171162
# 9                   Proctoscopy     43.091830     41.988873      43.617112
# 10                   Pneumo_Vax     65.584067     65.494412      65.429619
# 11                      Flu_Vac     70.028628     69.349234      69.111755
# 12                          LBW      5.932664      8.810020       7.998403
# 13                    Premature      9.934062     13.499591      12.418520
# 14                    Late_Care     16.214880     19.601022      18.579477
# 15             Infant_Mortality      6.454825      8.936729       7.751376
# 16                  Brst_Cancer     27.026827     26.563620      26.297522
# 17                   Col_Cancer     20.943483     21.770903      21.017630
# 18                          CHD    173.471726    226.275596     191.209591
# 19                  Lung_Cancer     47.222700     68.980162      59.836440
# 20                       Stroke     58.673185     71.333625      63.199561
# 21                      Obesity     22.957653     25.920915      24.268279
# 22              High_Blood_Pres     25.858719     27.823776      26.605606
# 23                     Diabetes      6.525373      9.013586       8.051581
# 24                    Uninsured   2696.504950   5095.014315   22915.228930
# 25             Elderly_Medicare   3996.236320   4348.756646   18626.272930
# 26            Disabled_Medicare    493.692405   1000.302658    3215.964421
# 27          Prim_Care_Phys_Rate     59.827063     50.701431      63.074699
# 28                 Dentist_Rate     36.493234     26.404294      33.746137
# 29  Community_Health_Center_Ind      2.000000      2.000000       1.000000
#
#         cluster4
# 0     995.000000
# 1   50904.069291
# 2      10.649843
# 3      24.768976
# 4      61.696850
# 5      11.728504
# 6       1.805984
# 7      82.577322
# 8      79.995811
# 9      43.038746
# 10     65.712227
# 11     69.640462
# 12      7.222852
# 13     11.280381
# 14     16.150695
# 15      6.387435
# 16     25.533695
# 17     22.176452
# 18    180.425982
# 19     58.913755
# 20     62.189850
# 21     23.637529
# 22     25.763671
# 23      7.573226
# 24   5201.655182
# 25   5905.833461
# 26   1013.009438
# 27     48.436378
# 28     28.956323
# 29      2.000000

# %%
#radar chart
#Main source: https://python-graph-gallery.com/392-use-faceting-for-radar-chart/

# Set data
df = pd.DataFrame({
'group': ['Cluster1','Cluster2','Cluster3','Cluster4'],
'Poverty': [df_clean1['Poverty'].mean(), df_clean2['Poverty'].mean(), df_clean3['Poverty'].mean(), df_clean4['Poverty'].mean()],
'PCPsNo': [df_clean1['Prim_Care_Phys_Rate'].mean(), df_clean2['Prim_Care_Phys_Rate'].mean(), df_clean3['Prim_Care_Phys_Rate'].mean(), df_clean4['Prim_Care_Phys_Rate'].mean()],
'Obesity': [df_clean1['Obesity'].mean(), df_clean2['Obesity'].mean(), df_clean3['Obesity'].mean(), df_clean4['Obesity'].mean()],
'High_Blood_Pres': [df_clean1['High_Blood_Pres'].mean(), df_clean2['High_Blood_Pres'].mean(), df_clean3['High_Blood_Pres'].mean(), df_clean4['High_Blood_Pres'].mean()],
'Inft_mor': [df_clean1['Infant_Mortality'].mean(), df_clean2['Infant_Mortality'].mean(), df_clean3['Infant_Mortality'].mean(), df_clean4['Infant_Mortality'].mean()]
}) 

# ------- PART 2: Apply to all individuals
# initialize the figure
my_dpi=96
plt.figure(figsize=(1000/my_dpi, 1000/my_dpi), dpi=my_dpi)
 
# Create a color palette:
my_palette = plt.cm.get_cmap("Set2", len(df.index))
 
# Loop to plot
for row in range(0, len(df.index)):
    make_spider( row=row, title='group '+df['group'][row], color=my_palette(row))

    
#plt.savefig('PAMradar.pdf')

print('Radar chart using PAM that shows the difference in features for the different clusters')
# Out:
# Radar chart using PAM that shows the difference in features for the different clusters
